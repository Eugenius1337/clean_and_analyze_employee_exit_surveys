# %% [markdown]
# # Clean and Analyze Employee Exit Surveys
# In this project, we will be working with exit surveys from employees of the Department of Education, Training and Employment (DETE) and the Technical and Further Education (TAFE) institute in Queensland, Australia. You can find the TAFE exit survey [here](https://data.gov.au/dataset/ds-qld-89970a3b-182b-41ea-aea2-6f9f17b5907e/details?q=exit%20survey) and the survey for the DETE [here](https://data.gov.au/dataset/ds-qld-fe96ff30-d157-4a81-851d-215f2a0fe26d/details?q=exit%20survey).
#
# We want to answer the following questions:
#
# * Are employees who only worked for the institutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been there longer?
#
# * Are younger employees resigning due to some kind of dissatisfaction? What about older employees?
#
# Below are some columns we'll be working with from the dete_survey.csv:
#
# * `ID`: An id used to identify the participant of the survey
# * `SeparationType`: The reason why the person's employment ended
# * `Cease Date`: The year or month the person's employment ended
# * `DETE Start Date`: The year the person began employment with the DETE
#
# Below are some columns we'll be working with from the tafe_survey.csv:
#
# * `Record ID`: An id used to identify the participant of the survey
# * `Reason for ceasing employment`: The reason why the person's employment ended
# * `LengthofServiceOverall. Overall Length of Service at Institute (in years)`: The length of the person's employment (in years)
#
# First, we will import our libraries and read in the datasets:

# %%
import pandas as pd
import numpy as np

# Read csv into pandas dataframe
dete_survey = pd.read_csv('dete_survey.csv')
tafe_survey = pd.read_csv('tafe_survey.csv')

# Avoids truncated output
pd.options.display.max_columns = 150
dete_survey.head(10)
# Out:
#    ID                    SeparationType Cease Date DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012            1984
# 1   2  Voluntary Early Retirement (VER)    08/2012      Not Stated
# 2   3  Voluntary Early Retirement (VER)    05/2012            2011
# 3   4         Resignation-Other reasons    05/2012            2005
# 4   5                    Age Retirement    05/2012            1970
# 5   6         Resignation-Other reasons    05/2012            1994
# 6   7                    Age Retirement    05/2012            1972
# 7   8                    Age Retirement    05/2012            1988
# 8   9         Resignation-Other reasons    07/2012            2009
# 9  10        Resignation-Other employer       2012            1997
#
#   Role Start Date                                      Position  \
# 0            2004                                Public Servant
# 1      Not Stated                                Public Servant
# ...

# %%
dete_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
# ID                                     822 non-null int64
# SeparationType                         822 non-null object
# Cease Date                             822 non-null object
# DETE Start Date                        822 non-null object
# Role Start Date                        822 non-null object
# Position                               817 non-null object
# Classification                         455 non-null object
# Region                                 822 non-null object
# Business Unit                          126 non-null object
# Employment Status                      817 non-null object
# Career move to public sector           822 non-null bool
# Career move to private sector          822 non-null bool
# Interpersonal conflicts                822 non-null bool
# Job dissatisfaction                    822 non-null bool
# ...

# %%
tafe_survey.head(10)
# Out:
#       Record ID                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
# 5  6.341475e+17  Southern Queensland Institute of TAFE
# 6  6.341520e+17         Barrier Reef Institute of TAFE
# 7  6.341537e+17  Southern Queensland Institute of TAFE
# 8  6.341579e+17  Southern Queensland Institute of TAFE
# 9  6.341588e+17         Barrier Reef Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)          2010.0              Contract Expired
# 1  Non-Delivery (corporate)          2010.0                    Retirement
# 2       Delivery (teaching)          2010.0                    Retirement
# ...

# %%
tafe_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 72 columns):
# Record ID                                                                                                                                                        702 non-null float64
# Institute                                                                                                                                                        702 non-null object
# WorkArea                                                                                                                                                         702 non-null object
# CESSATION YEAR                                                                                                                                                   695 non-null float64
# ...

# %% [markdown]
# From our observations, we can conclude that:
# * The `dete_survey` dataset includes `Not Stated` values, which should be `NaN` instead.
# * Both datasets include columns that are unnecessary to our analysis.
# * Many of the columns in both datasets are the same, but have different names.
# * There are multiple answers that indicate the employee resigned due to dissatisfaction.

# %% [markdown]
# # Identify Missing Values and Drop Unnecessary Columns
# First, we will handle the `Not Stated` values and drop the columns we don't need.

# %%
# To handle the Not Stated values, we read in the dete_survey.csv again, but set na_values = 'Not Stated'
dete_survey = pd.read_csv('dete_survey.csv', na_values = 'Not Stated')

dete_survey.head(10)
# Out:
#    ID                    SeparationType Cease Date  DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
# 5   6         Resignation-Other reasons    05/2012           1994.0
# 6   7                    Age Retirement    05/2012           1972.0
# 7   8                    Age Retirement    05/2012           1988.0
# 8   9         Resignation-Other reasons    07/2012           2009.0
# 9  10        Resignation-Other employer       2012           1997.0
#
#    Role Start Date                                      Position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# ...

# %%
# Now, we will drop columns 17-48 in the dete_survey dataset, and columns 17-65 in the tafe_survey dataset.
dete_survey_updated = dete_survey.drop(dete_survey.columns[28:49], axis = 1)
tafe_survey_updated = tafe_survey.drop(tafe_survey.columns[17:66], axis = 1)

dete_survey_updated.columns
# Out:
# Index(['ID', 'SeparationType', 'Cease Date', 'DETE Start Date',
#        'Role Start Date', 'Position', 'Classification', 'Region',
#        'Business Unit', 'Employment Status', 'Career move to public sector',
#        'Career move to private sector', 'Interpersonal conflicts',
#        'Job dissatisfaction', 'Dissatisfaction with the department',
#        'Physical work environment', 'Lack of recognition',
#        'Lack of job security', 'Work location', 'Employment conditions',
#        'Maternity/family', 'Relocation', 'Study/Travel', 'Ill Health',
#        'Traumatic incident', 'Work life balance', 'Workload',
#        'None of the above', 'Gender', 'Age', 'Aboriginal', 'Torres Strait',
#        'South Sea', 'Disability', 'NESB'],
#       dtype='object')

# %%
tafe_survey_updated.columns
# Out:
# Index(['Record ID', 'Institute', 'WorkArea', 'CESSATION YEAR',
#        'Reason for ceasing employment',
#        'Contributing Factors. Career Move - Public Sector ',
#        'Contributing Factors. Career Move - Private Sector ',
#        'Contributing Factors. Career Move - Self-employment',
#        'Contributing Factors. Ill Health',
#        'Contributing Factors. Maternity/Family',
#        'Contributing Factors. Dissatisfaction',
#        'Contributing Factors. Job Dissatisfaction',
#        'Contributing Factors. Interpersonal Conflict',
#        'Contributing Factors. Study', 'Contributing Factors. Travel',
#        'Contributing Factors. Other', 'Contributing Factors. NONE',
#        'Gender. What is your Gender?', 'CurrentAge. Current Age',
#        'Employment Type. Employment Type', 'Classification. Classification',
#        'LengthofServiceOverall. Overall Length of Service at Institute (in years)',
# ...

# %% [markdown]
# As we can see above, the values that were `Not Stated` are now `NaN`. Also, we removed columns that do not help our analysis. Now, we only have columns that provide information on dissatisfaction.

# %% [markdown]
# # Clean Column Names
# Now, we will work on the columns with the same values, but different names.
#
# First, we will clean the column names in the `dete_survey_updated` dataset:
# * Make all the capitalization lowercase.
# * Remove any trailing whitespace from the end of the strings.
# * Replace spaces with underscores ('_').

# %%
dete_survey_updated.columns = dete_survey_updated.columns.str.lower().str.replace(' ', '_').str.replace('\s', '')

print(dete_survey_updated.columns)

dete_survey_updated.head(10)
# Out:
# Index(['id', 'separationtype', 'cease_date', 'dete_start_date',
#        'role_start_date', 'position', 'classification', 'region',
#        'business_unit', 'employment_status', 'career_move_to_public_sector',
#        'career_move_to_private_sector', 'interpersonal_conflicts',
#        'job_dissatisfaction', 'dissatisfaction_with_the_department',
#        'physical_work_environment', 'lack_of_recognition',
#        'lack_of_job_security', 'work_location', 'employment_conditions',
#        'maternity/family', 'relocation', 'study/travel', 'ill_health',
#        'traumatic_incident', 'work_life_balance', 'workload',
#        'none_of_the_above', 'gender', 'age', 'aboriginal', 'torres_strait',
#        'south_sea', 'disability', 'nesb'],
#       dtype='object')
#    id                    separationtype cease_date  dete_start_date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# ...

# %% [markdown]
# To improve efficiency, we change the names of these columns. Having lowercase column names allows us to work quickly with less errors as we don't have to worry about capitalization.
#
# Next, we will rename some of the columns in the `tafe_survey_updated` dataset.

# %%
# We make a dictionary with the columns we want to rename as keys, and the new names we want as their values.
new_columns = {'Record ID':'id', 'CESSATION YEAR': 'cease_date', 'Reason for ceasing employment': 'separation_type', 
               'Gender. What is your Gender?': 'gender', 'CurrentAge. Current Age': 'age', 
              'Employment Type. Employment Type': 'employment_status', 'Classification. Classification': 'position',
              'LengthofServiceOverall. Overall Length of Service at Institute (in years)': 'institute_service',
              'LengthofServiceCurrent. Length of Service at current workplace (in years)': 'role_service'}

tafe_survey_updated = tafe_survey_updated.rename(new_columns, axis = 1)

tafe_survey_updated.head(10)
# Out:
#              id                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
# 5  6.341475e+17  Southern Queensland Institute of TAFE
# 6  6.341520e+17         Barrier Reef Institute of TAFE
# 7  6.341537e+17  Southern Queensland Institute of TAFE
# 8  6.341579e+17  Southern Queensland Institute of TAFE
# 9  6.341588e+17         Barrier Reef Institute of TAFE
#
#                    WorkArea  cease_date   separation_type  \
# 0  Non-Delivery (corporate)      2010.0  Contract Expired
# 1  Non-Delivery (corporate)      2010.0        Retirement
# 2       Delivery (teaching)      2010.0        Retirement
# 3  Non-Delivery (corporate)      2010.0       Resignation
# 4       Delivery (teaching)      2010.0       Resignation
# ...

# %% [markdown]
# Again, we change the names of the columns to improve efficiency. We will handle the other unaltered columns later.

# %% [markdown]
# # Filtering the Data
# Next, we will be filtering our two datasets to find only those who `Resigned` from work.

# %%
print(dete_survey_updated['separationtype'].value_counts())
print('\n')
print(tafe_survey_updated['separation_type'].value_counts())
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: separationtype, dtype: int64
#
#
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# Name: separation_type, dtype: int64

# %% [markdown]
# The `dete_survey_updated` dataset contains 3 different `Resignation` types, and `tafe_survey_updated` contains 1.
#
# We will now extract them:

# %%
# We first update the Resignation values to just say Resignation
dete_survey_updated['separationtype'] = dete_survey_updated['separationtype'].str.split('-').str[0]

dete_survey_updated['separationtype'].value_counts()
# Out:
# Resignation                         311
# Age Retirement                      285
# Voluntary Early Retirement (VER)     67
# Ill Health Retirement                61
# Other                                49
# Contract Expired                     34
# Termination                          15
# Name: separationtype, dtype: int64

# %%
dete_resignations = dete_survey_updated[dete_survey_updated['separationtype'] == 'Resignation'].copy()

tafe_resignations = tafe_survey_updated[tafe_survey_updated['separation_type'] == 'Resignation'].copy()

# %% [markdown]
# Now, we have the rows with `Resignation` as their reason for leaving.

# %% [markdown]
# # Verifying the Data
# We will now verify that our data does not contain any major inconsistencies. We will be verifying the `cease_date` and `dete_start_date` columns.
#
# If either column has dates past the current date, or the `dete_start_date` is older than 1940, we will have to consider removing them. We choose 1940 as the cutoff date because the majority of people working in this field have started work in their 20's.

# %%
dete_resignations['cease_date'].value_counts()
# Out:
# 2012       126
# 2013        74
# 01/2014     22
# 12/2013     17
# 06/2013     14
# 09/2013     11
# 07/2013      9
# 11/2013      9
# 10/2013      6
# 08/2013      4
# 05/2012      2
# 05/2013      2
# 2010         1
# 07/2006      1
# 07/2012      1
# 09/2010      1
# Name: cease_date, dtype: int64

# %% [markdown]
# ### dete_resignations
#
# We want to extract just the year, so we will be using vectorized string methods to do so. Then, we will convert the year to a float.

# %%
dete_resignations['cease_date'] = dete_resignations['cease_date'].str.split('/').str[-1]
dete_resignations['cease_date'] = dete_resignations['cease_date'].astype(float)

dete_resignations['cease_date'].value_counts()
# Out:
# 2013.0    146
# 2012.0    129
# 2014.0     22
# 2010.0      2
# 2006.0      1
# Name: cease_date, dtype: int64

# %%
dete_resignations['dete_start_date'].value_counts()
# Out:
# 2011.0    24
# 2008.0    22
# 2007.0    21
# 2012.0    21
# 2010.0    17
# 2005.0    15
# 2004.0    14
# 2009.0    13
# 2006.0    13
# 2013.0    10
# 2000.0     9
# 1999.0     8
# 1996.0     6
# 2002.0     6
# 1992.0     6
# 1998.0     6
# 2003.0     6
# 1994.0     6
# 1993.0     5
# 1990.0     5
# 1980.0     5
# 1997.0     5
# 1991.0     4
# 1989.0     4
# 1988.0     4
# 1995.0     4
# 2001.0     3
# 1985.0     3
# 1986.0     3
# 1983.0     2
# 1976.0     2
# 1974.0     2
# 1971.0     1
# 1972.0     1
# 1984.0     1
# 1982.0     1
# 1987.0     1
# 1975.0     1
# 1973.0     1
# 1977.0     1
# 1963.0     1
# Name: dete_start_date, dtype: int64

# %% [markdown]
# ### tafe_resignations

# %%
tafe_resignations['cease_date'].value_counts()
# Out:
# 2011.0    116
# 2012.0     94
# 2010.0     68
# 2013.0     55
# 2009.0      2
# Name: cease_date, dtype: int64

# %% [markdown]
# # Creating a New Column
# Previously, we renamed some columns. One of which in the `tafe_survey_updated` dataframe, we renamed the `service` column to `institute_service`. Now, we will calculate this `institute_service` by subtracting the `dete_start_date` from the `cease_date`. We will then place these values into a new column in our resignations dataframe named `institute_service`.

# %%
dete_resignations['institute_service'] = dete_resignations['cease_date'] - dete_resignations['dete_start_date']

dete_resignations['institute_service']
# Out:
# 3       7.0
# 5      18.0
# 8       3.0
# 9      15.0
# 11      3.0
#        ...
# 808     3.0
# 815     2.0
# 816     2.0
# 819     5.0
# 821     NaN
# Name: institute_service, Length: 311, dtype: float64

# %% [markdown]
# # Identifying Dissatisfied Employees
# Now that we have the length of employment for the former employees, we will identify which employees resigned due to dissatisfaction.
#
# Below are the columns we'll be using to categorize employees as "dissatisfied" from each dataframe.
#
# tafe_survey_updated:
# * Contributing Factors. Dissatisfaction
# * Contributing Factors. Job Dissatisfaction
#
# dafe_survey_updated:
# * job_dissatisfaction
# * dissatisfaction_with_the_department
# * physical_work_environment
# * lack_of_recognition
# * lack_of_job_security
# * work_location
# * employment_conditions
# * work_life_balance
# * workload
#
# If an employee indicated any column above as dissatisfied, we will place them into a new column.
#
# The new column will be structured as followed:
#
# Convert the values in the `Contributing Factors. Dissatisfaction` and `Contributing Factors. Job Dissatisfaction` columns in the `tafe_resignations` dataframe to `True`, `False`, or `NaN` values.
#
# If any of the columns listed above contain a `True` value, we'll add a `True` value to a new column named `dissatisfied`. To accomplish this, we'll use the DataFrame.any() method to do the following:
#
# * Return True if any element in the selected columns above is True
# * Return False if none of the elements in the selected columns above is True
# * Return NaN if the value is NaN

# %%
tafe_resignations['Contributing Factors. Dissatisfaction'].value_counts()
# Out:
# -                                         277
# Contributing Factors. Dissatisfaction      55
# Name: Contributing Factors. Dissatisfaction, dtype: int64

# %%
tafe_resignations['Contributing Factors. Job Dissatisfaction'].value_counts()
# Out:
# -                      270
# Job Dissatisfaction     62
# Name: Contributing Factors. Job Dissatisfaction, dtype: int64

# %%
def update_vals(val):
    if val == '-':
        return False
    elif pd.isnull(val):
        return np.nan
    else:
        return True
    
tafe_resignations['dissatisfied'] = tafe_resignations[['Contributing Factors. Dissatisfaction', 'Contributing Factors. Job Dissatisfaction']].applymap(update_vals).any(1, skipna = False)

tafe_resignations_up = tafe_resignations.copy()

tafe_resignations_up['dissatisfied'].value_counts(dropna = False)
# Out:
# False    241
# True      91
# NaN        8
# Name: dissatisfied, dtype: int64

# %%
dete_resignations['dissatisfied'] = dete_resignations[['job_dissatisfaction', 'dissatisfaction_with_the_department', 'physical_work_environment', 'lack_of_recognition', 'lack_of_job_security', 'work_location', 'employment_conditions', 'work_life_balance', 'workload']].any(1, skipna = False)

dete_resignations_up = dete_resignations.copy()

dete_resignations_up['dissatisfied'].value_counts(dropna = False)
# Out:
# False    162
# True     149
# Name: dissatisfied, dtype: int64

# %% [markdown]
# We now have the `True`, `False`, and `NaN` values.

# %% [markdown]
# # Combining the Data
# So far, we have renamed our columns, dropped irrelevant data, verified the quality of our data, created the `institute_service` column, cleaned the `Contributing Factors` column, and created a new column identifying employees who were dissatisfied.
#
# Now, we can combine our two datasets into one. Our end goal is to aggregate one entire dataset on the `institute_service` column.

# %%
dete_resignations_up['institute'] = 'DETE'

tafe_resignations_up['institute'] = 'TAFE'

# We combine the datasets using pd.concat()
combined = pd.concat([dete_resignations_up, tafe_resignations_up], ignore_index = True, sort = True)

# %% [markdown]
# Now, we will verify the columns we need to drop that have less than a certain amount of not-null values.

# %%
combined.notnull().sum().sort_values()
# Out:
# torres_strait                                            0
# south_sea                                                3
# aboriginal                                               7
# disability                                               8
# nesb                                                     9
# business_unit                                           32
# classification                                         161
# region                                                 265
# role_start_date                                        271
# dete_start_date                                        283
# role_service                                           290
# lack_of_job_security                                   311
# employment_conditions                                  311
# work_location                                          311
# job_dissatisfaction                                    311
# lack_of_recognition                                    311
# ...

# %%
combined_updated = combined.dropna(thresh = 500, axis = 1).copy()

combined_updated.head(10)
# Out:
#            age  cease_date dissatisfied    employment_status  gender    id  \
# 0        36-40      2012.0        False  Permanent Full-time  Female   4.0
# 1        41-45      2012.0         True  Permanent Full-time  Female   6.0
# 2        31-35      2012.0        False  Permanent Full-time  Female   9.0
# 3        46-50      2012.0         True  Permanent Part-time  Female  10.0
# 4        31-35      2012.0        False  Permanent Full-time    Male  12.0
# 5        36-40      2012.0        False  Permanent Full-time  Female  13.0
# 6        31-35      2012.0         True  Permanent Full-time    Male  15.0
# 7  61 or older      2012.0         True  Permanent Part-time    Male  17.0
# 8        56-60      2012.0        False  Permanent Full-time    Male  21.0
# 9        51-55      2012.0        False  Permanent Part-time  Female  22.0
#
#   institute institute_service          position
# 0      DETE                 7           Teacher
# ...

# %% [markdown]
# # Cleaning the Service Column
# We now have to clean the `institute`

# %%
combined_updated['institute_service'].value_counts(dropna = False)
# Out:
# NaN                   88
# Less than 1 year      73
# 1-2                   64
# 3-4                   63
# 5-6                   33
# 11-20                 26
# 5.0                   23
# 1.0                   22
# 7-10                  21
# 0.0                   20
# 3.0                   20
# 6.0                   17
# 4.0                   16
# 2.0                   14
# 9.0                   14
# 7.0                   13
# More than 20 years    10
# 13.0                   8
# 8.0                    8
# 15.0                   7
# 20.0                   7
# 14.0                   6
# 12.0                   6
# 17.0                   6
# 22.0                   6
# 10.0                   6
# 16.0                   5
# 18.0                   5
# 11.0                   4
# 23.0                   4
# 24.0                   4
# 19.0                   3
# 32.0                   3
# 39.0                   3
# 21.0                   3
# 28.0                   2
# 30.0                   2
# ...

# %% [markdown]
# The values have different values such as `26.0`, `3-4`, and `More than 20 years`.
#
# We will be using the following updated ranges:
#
# * `New`: Less than 3 years at a company
# * `Experienced`: 3-6 years at a company
# * `Established`: 7-10 years at a company
# * `Veteran`: 11 or more years at a company
